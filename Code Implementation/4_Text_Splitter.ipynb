# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Text Splitters in LangChain

# %% [markdown]
# #### 1. Length-Based Text Splitting

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter

# Load document
loader = TextLoader(file_path='../1_Datasets/Harry_Potter.txt') 
docs = loader.load()

# %%
# Configure splitter
splitter = CharacterTextSplitter(
    chunk_size=200, 
    chunk_overlap=0, 
    separator="")

# %%
# Split documents
result = splitter.split_documents(docs)
print(result[0].page_content) # printing the first splitted document
# Out:
# Harry Potter and the Sorcerer's Stone
#
# CHAPTER ONE
#
# THE BOY WHO LIVED
#
# Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say that they were perfectly normal, thank you very much. Th

# %% [markdown]
# #### 2. Text-Structure Based Splitting

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text = """My name is salman khan
I am 60 years old

I live in India
How are you
"""

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 10, 
    chunk_overlap = 0
)

chunks = text_splitter.split_text(text)
print(chunks)
# Out:
# ['My name is', 'salman', 'khan', 'I am 60', 'years old', 'I live in', 'India', 'How are', 'you']

# %%
# let's use same splitter for bigger documents
rec_text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500, 
    chunk_overlap = 50
)

chunks = rec_text_splitter.split_documents(docs)
print(len(chunks))
# Out:
# 1173

# %%
for i, chunk in enumerate(chunks): 
    print(f"Chunk {i+1}")
    print(chunk.page_content)
    print("-"*30)

# %% [markdown]
# #### 3. Document Structure-Based Splitting

# %% [markdown]
# ##### 3.1 Working with Markdown

# %%
markdown_text = """
# Harry Potter

## Introduction
Harry Potter is a fictional character created by British author J.K. Rowling. 
He is the main protagonist of the Harry Potter book series, which follows his journey as a young wizard.

## Early Life
Harry Potter was born to James Potter and Lily Potter. When he was a baby, his parents were killed by the 
dark wizard Lord Voldemort. Harry survived the attack and was left with a lightning-shaped scar on his forehead.

## Hogwarts School
At the age of eleven, Harry discovers that he is a wizard and receives a letter inviting him to attend Hogwarts 
School of Witchcraft and Wizardry. There, he makes close friends:

- Ron Weasley
- Hermione Granger

## Main Characters
 - Harry Potter
 - Hermione Granger
 - Ron Weasley
 - Lord Voldemort

## Conclusion
Harry Potter is one of the most popular and influential fantasy series in the world. 
The story continues to inspire readers of all ages through its memorable characters, 
magical world, and powerful lessons.
"""

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

md_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.MARKDOWN, 
    chunk_size = 250, 
    chunk_overlap = 0
)

chunks = md_splitter.split_text(markdown_text)

# %%
for i, chunk in enumerate(chunks): 
    print(f"Chunk {i+1}")
    print(chunk)
    print("--"*30)
# Out:
# Chunk 1
# # Harry Potter
#
# ## Introduction
# Harry Potter is a fictional character created by British author J.K. Rowling.
# He is the main protagonist of the Harry Potter book series, which follows his journey as a young wizard.
# ------------------------------------------------------------
# Chunk 2
# ## Early Life
# Harry Potter was born to James Potter and Lily Potter. When he was a baby, his parents were killed by the
# dark wizard Lord Voldemort. Harry survived the attack and was left with a lightning-shaped scar on his forehead.
# ------------------------------------------------------------
# Chunk 3
# ## Hogwarts School
# At the age of eleven, Harry discovers that he is a wizard and receives a letter inviting him to attend Hogwarts
# School of Witchcraft and Wizardry. There, he makes close friends:
#
# - Ron Weasley
# - Hermione Granger
# ------------------------------------------------------------
# Chunk 4
# ## Main Characters
#  - Harry Potter
#  - Hermione Granger
#  - Ron Weasley
#  - Lord Voldemort
# ------------------------------------------------------------
# Chunk 5
# ## Conclusion
# Harry Potter is one of the most popular and influential fantasy series in the world.
# The story continues to inspire readers of all ages through its memorable characters,
# magical world, and powerful lessons.
# ------------------------------------------------------------

# %% [markdown]
# ##### 3.2 Working with Python Code

# %%
python_code = """
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

md_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.MARKDOWN, 
    chunk_size = 250, 
    chunk_overlap = 0
)

chunks = md_splitter.split_text(markdown_text)

for i, chunk in enumerate(chunks): 
    print(f"Chunk {i+1}")
    print(chunk)
    print("--"*30)
"""

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

python_splitter = RecursiveCharacterTextSplitter.from_language(
    language = Language.PYTHON,
    chunk_size=145, 
    chunk_overlap=0)

chunks = python_splitter.split_text(python_code)
print(len(chunks))
# Out:
# 4

# %%
for i, chunk in enumerate(chunks): 
    print(f"Chunk {i+1}")
    print(f"The size of chunk {i+1}: {len(chunk)}")
    print(chunk)
    print()
# Out:
# Chunk 1
# The size of chunk 1: 77
# from langchain_text_splitters import RecursiveCharacterTextSplitter, Language
#
# Chunk 2
# The size of chunk 2: 139
# md_splitter = RecursiveCharacterTextSplitter.from_language(
#     language=Language.MARKDOWN,
#     chunk_size = 250,
#     chunk_overlap = 0
# )
#
# Chunk 3
# The size of chunk 3: 46
# chunks = md_splitter.split_text(markdown_text)
#
# Chunk 4
# The size of chunk 4: 97
# for i, chunk in enumerate(chunks):
#     print(f"Chunk {i+1}")
#     print(chunk)
#     print("--"*30)

# %% [markdown]
# ##### 3.3 Working with JavaScript Code

# %%
javascript_text = """
// Function is called, the return value will end up in x
let x = myFunction(4, 3);

function myFunction(a, b) {
// Function returns the product of a and b
  return a * b;
}
"""

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

js_splitter = RecursiveCharacterTextSplitter.from_language( 
    language=Language.JS, 
    chunk_size = 65, 
    chunk_overlap = 0
)
chunks = js_splitter.split_text(javascript_text)
len(chunks)
# Out:
# 4

# %%
for i, chunk in enumerate(chunks): 
    print(f"Chunk {i+1}")
    print(f"The size of chunk {i+1}: {len(chunk)}")
    print(chunk)
    print()
# Out:
# Chunk 1
# The size of chunk 1: 56
# // Function is called, the return value will end up in x
#
# Chunk 2
# The size of chunk 2: 25
# let x = myFunction(4, 3);
#
# Chunk 3
# The size of chunk 3: 27
# function myFunction(a, b) {
#
# Chunk 4
# The size of chunk 4: 60
# // Function returns the product of a and b
#   return a * b;
# }

# %% [markdown]
# _*🎉 And all set. We just completed second important component (**Text Splitter**) of RAG*_
